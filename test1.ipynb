# %%
import numpy

# %%
numpy.random.normal(0, 1, 5)
# Out:
# array([-0.8279771 ,  0.79492307,  1.11867521, -0.0478016 , -1.3661395 ])

# %%
numpy.random.normal(3,2,[3,4])
# Out:
# array([[ 5.85719588,  3.69284773,  2.32546831,  4.79083642],
#        [ 1.34072115, -1.661721  ,  3.715456  ,  4.19937001],
#        [ 7.80862782,  1.7931323 ,  3.23783886,  4.47033362]])

# %%
numpy.random.normal(0, 1, 1)
# Out:
# array([-2.01565819])

# %%
numpy.random.normal(0, 1, 5).tolist()
# Out:
# [0.3039291805795685,
#  0.885505575852712,
#  -1.4324792320757982,
#  0.7144727068374861,
#  -0.4997366951612458]

# %%
# %matplotlib inline
#Uniquement sous jupyter

# %%
import matplotlib.pyplot as plt

# %%
x = numpy.random.normal(0, 4, 500)

plt.hist(x, bins=15, ec = 'white')
plt.show()

# %%
import pandas as pd

# %%
import scipy

# %%
fichier = 'barometre-resultats-data.xlsx'
data = pd.read_excel(fichier, engine='openpyxl')

# %%
data
# Out:
#                                                 mesure  \
# 0    Offrir une scolarisation inclusive à tous les ...
# 1    Offrir une scolarisation inclusive à tous les ...
# 2              Promouvoir l'engagement chez les jeunes
# 3               Aide de France Relance aux entreprises
# 4     Numérisation des petites et moyennes entreprises
# ..                                                 ...
# 875  Renforcer les compétences de la nation - plan ...
# 876  Apprendre à nager et à circuler à vélo en tout...
# 877  Apprendre à nager et à circuler à vélo en tout...
# 878       Simplifier l’accès à l’aide juridictionnelle
# 879  Garantir l'égalité professionnelle entre les f...
#
#                                             indicateur  \
# 0    Nombre d’unités locales d’inclusion scolaires ...
# 1    Nombre de classes adaptées à la scolarisation ...
# 2    Nombre de volontaires ayant réalisé au moins u...
# 3    Nombre d’entreprises industrielles (dont PME) ...
# ...
